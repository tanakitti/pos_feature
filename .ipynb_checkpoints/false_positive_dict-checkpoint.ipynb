# %%
import pandas as pd

# %%
df = pd.read_csv('./data/thai_words_in_zon.csv')

# %%
df
# Out:
#                  word label
# 0                  กก   NaN
# 1                 กขน   NaN
# 2                  กค   NaN
# 3                  กง   NaN
# 4                 กซ์   NaN
# 5                  กฎ   NaN
# 6              กฎหมาย     1
# 7             กฎเกณฑ์     1
# 8                  กฏ   NaN
# 9               กดดัน   NaN
# 10             กดปุ่ม   NaN
# 11              กดหัว   NaN
# 12                 กท   NaN
# 13                กทม   NaN
# 14                 กน   NaN
# 15                กนก   NaN
# 16                 กบ   NaN
# 17                กปิ   NaN
# 18                กพส   NaN
# 19    กฟดกสดสฟฟสดสกสห   NaN
# 20                 กม   NaN
# 21                กยศ   NaN
# 22                 กร   NaN
# 23                กรก   NaN
# 24            กรกฎาคม     1
# 25                กรง   NaN
# 26               กรณี   NaN
# 27                กรน   NaN
# 28                กรม   NaN
# 29             กรมท่า     1
# ...               ...   ...
# 7772              ไอ่   NaN
# ...
